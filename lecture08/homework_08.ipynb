# %% [markdown]
# (lecture08:homework)=
# # Homework 8
#
# + Type your name and email in the "Student details" section below.
# + Develop the code and generate the figures you need to solve the problems using this notebook.
# + For the answers that require a mathematical proof or derivation you can either:
#
#     - Type the answer using the built-in latex capabilities. In this case, simply export the notebook as a pdf and upload it on gradescope; or
#     - You can print the notebook (after you are done with all the code), write your answers by hand, scan, turn your response to a single pdf, and upload on gradescope.
#
# + The total homework points are 100. Please note that the problems are not weighed equally.
#
# ```{note}
# + Please match all the pages corresponding to each of the questions when you submit on gradescope.
# ```

# %% [markdown]
# ## Student details
#
# + **First Name:** Timothy
# + **Last Name:** Lee
# + **Email:** lee5695@purdue.edu

# %% [markdown]
# ## Problem 1 - Medical test analysis
#
# Disclaimer: This example is a modified version of the one found in a 2013 lecture on Bayesian Scientific Computing taught by Prof. Nicholas Zabaras.
# I am not sure where the original problem is coming from.
#
# We are tasked with assessing the usefulness of a tuberculosis test.
# The prior information I is:
#
# > The percentage of the population infected by tuberculosis is 0.4\%.
# We have run several experiments and determined that:
# + If a tested patient has the disease, then 80\% of the time the test comes out positive.
# + If a tested patient does not have the disease, then 90\% of the time the test comes out negative.
#
# To facilitate your analysis, consider the following logical sentences concerning a patient:
#
# > A: The patient is tested and the test is positive.
#
# > B: The patient has tuberculosis.
#
# A. Find the probability that the patient has tuberculosis (before looking at the result of the test), i.e., $p(B|I)$. This is known as the base rate or the prior probability.

# %% [markdown]
# **To make this problem easier to visualize, I drew the following tree diagram:**
#
# $\hspace{3.5 cm} $ Population <br>
# $\hspace{2.75 cm} 0.004 / \hspace{1 cm} \backslash 0.996$ <br>
# $\hspace{1.5 cm} B \hspace{5 cm}\neg B$<br>
# $\hspace{0.375 cm} 0.8 / \hspace{.75 cm} \backslash 0.2 \hspace{3 cm} 0.1 / \hspace{1 cm} \backslash 0.9$ <br>
# $A\hspace{2.125 cm} \neg A \hspace{2.625 cm} A \hspace{2.125 cm} \neg A$

# %% [markdown]
# **Answer:**
#
# $p(B|I) = \frac{0.4}{100} = 0.004$

# %% [markdown]
# B. Find the probability that the test is positive given that the patient has tuberculosis, i.e., $p(A|B,I)$.

# %% [markdown]
# **Answer:**
#
# $p(A|B,I) = \frac{80}{100} = 0.8$

# %% [markdown]
# C. Find the probability that the test is positive given that the patient does not have tuberculosis, i.e., $p(A|\neg B, I)$.

# %% [markdown]
# **Answer:**
#
# $p(A|\neg B, I) = 1 - p(\neg A|\neg B, I) = 1 - 0.9 = 0.1$

# %% [markdown]
# D. Find the probability that a patient that tested positive has tuberculosis, i.e., $p(B|A,I)$.

# %% [markdown]
# **Answer:**
#
# $p(B|A,I) = $
# <br><br>
# $ = \frac{0.8 \cdot 0.004}{0.8 \cdot 0.004 + 0.1 \cdot 0.996}$
# <br><br>
# $ =\frac{0.0032}{0.1028}$
# <br><br>
# $ = 0.0311284047 $

# %% [markdown]
# E. Find the probability that a patient that tested negative has tuberculosis, i.e., $p(B|\neg A, I)$. Does the test change our prior state of knowledge about about the patient? Is the test useful?

# %% [markdown]
# **Answer:**
# <br><br>
# $p(B|\neg A,I) =$
# <br><br>
# $ = \frac{0.2 \cdot 0.004}{0.2 \cdot 0.004 + 0.9 \cdot 0.996}$
# <br><br>
# $ = \frac{0.008}{0.8972}$
# <br><br>
# $ = 0.00891662951 $

# %% [markdown]
# F. What would a good test look like? Find values for
#
# $$
# p(A|B,I)= p(\text{test is positive} |\text{has tuberculosis},I),
# $$
#
# and
#
# $$
# p(A| \neg B, I) = p(\text{test is positive}|\text{does not have tuberculosis}, I),
# $$
#
# so that
#
# $$
# p(B|A, I) = p(\text{has tuberculosis}|\text{test is positive}, I) = 0.99.
# $$
#
# There are more than one solutions. How would you pick a good one? Thinking in this way can help you set goals if you work in R\&D. If you have time, try to figure out whether or not there exists such an accurate test for tuberculosis

# %% [markdown]
# **Answer:**
# <br><br>
# $ p(B|A, I) = 0.99 = \frac{0.004x_a}{0.004x_a + 0.996y_b}$ where $x_a = p(A|B,I)$ and $y_b = p(A| \neg B, I)$
# <br><br>
# $y_b = \frac{0.00004}{0.9860}x_a$
# <br><br>
# Choosing 95% (sensitivity) for $x_a$, which is the true positive rate yields:
# <br><br>
# $y_b = 3.85395538E-5 ≈ 0.0000385$
# <br><br>
# Because $y_b$ represents the false positive rate, which is 0.0038%, this is incredibly low. Picking a good solution would likely minimize the false negative rate, which is $(1-x_a) \cdot 0.004$, because false negatives are extremely deadly. In the real world, a test with this level of accuracy is incredibly difficult to create, so oftentimes a less accurate test is used for initial screening. Then, based on symptoms and the result of the test, if a more accurate test can be used, saving these for more critical scenarios as these are often more expensive. An alternative method is to also use the cheaper test twice, which is common for things like at-home pregnancy tests.
# <br><br>
# For tuberculosis, the tests that doctors typically use have a 94% sensitivity (true positive) and 97% specificity (true negative). While these numbers appear quite close to my calculations, my false positive rate of 0.0000385 is significantly lower than their false positive rate of (1-0.97) = 0.03. Thus, the real-world tests are not perfect, but using the methods I mentioned above would likely help mitigate this.

# %% [markdown]
# Run the following code to convert the notebook to a pdf. Verify that the file path to the notebook is correct.

# %%
from google.colab import drive
drive.mount('/content/drive')
# !apt-get install inkscape texlive texlive-xetex texlive-latex-extra pandoc --quiet
# !pip install pypandoc --quiet
# !jupyter nbconvert --to PDF '/content/drive/MyDrive/Colab Notebooks/Copy of homework_08.ipynb'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Reading package lists...
# Building dependency tree...
# Reading state information...
# inkscape is already the newest version (1.1.2-3ubuntu1).
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# texlive is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 132 not upgraded.
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Copy of homework_08.ipynb to PDF
# [NbConvertApp] Writing 65451 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] CRITICAL | xelatex failed: ['xelatex', 'notebook.tex', '-quiet']
# ...
